# %% [markdown]
# # Prepare BARRA-C2 data for analysis
#
# - Run tas average for each state greater metro region

# %%
import xarray as xr
import os
import geopandas as gpd
import regionmask

# %% [markdown]
# ### User configuraiton

# %%
years = range(2021, 2024)

# %%
barra_path = "/g/data/ob53/BARRA2/output/reanalysis/AUST-04/BOM/ERA5/historical/hres/BARRA-C2/v1/1hr/"
write_path = "/home/565/ad1803/Hot_Cloudy/Demand/sanaa_work/tas/"

# %%
fy = str(min(years))
ly = str(max(years))

variables = {
    "tas": [
        barra_path + "tas/latest/",  # directory containing monthly files
        "lat",  # latitude coordinate name in files
        "lon",  # longitude coordinate name in files
        write_path + "tas/tas_barra-c2_hourly_" + fy + "-" + ly + "_FILTERED",
        "tas",  # original variable name
        "tas",  # new variable name
    ]
}

month_str = ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"]

# %% [markdown]
# ### Load & filter region shape file

# %%
shp_path = "/home/565/ad1803/Hot_Cloudy/Demand/sanaa_work/shapefiles/GCCSA_2021_AUST_GDA2020.shp"
gdf = gpd.read_file(shp_path)

# %%
#keep only regions that match Carl's solar areas
gdf = gdf[gdf["GCC_CODE21"].isin(["1GSYD", "2GMEL", "3GBRI","4GADE","6GHOB","8ACTE"])]
#gdf

# %%
# Ensure geographic CRS
if gdf.crs is None or gdf.crs.to_epsg() != 4326:
    gdf = gdf.to_crs(epsg=4326)

# %%
#rasterise shapefiles
# Build regions directly from GeoDataFrame
regions = regionmask.from_geopandas(gdf, names="GCC_NAME21", name="GCCSA21")

# %% [markdown]
# ### Functions

# %%
# Open multiple hourly files and subset to lat/lon slices
def open_hourly(file_list, lat_slice, lon_slice, lat_name="lat", lon_name="lon"):

    def preprocess(ds):
        ds = ds.rename({lat_name: "lat", lon_name: "lon"})
        return ds.sel(lon=lon_slice, lat=lat_slice)

    ds = xr.open_mfdataset(
        file_list,
        preprocess=preprocess,
        chunks={"time": "200MB"},
        combine="by_coords",
        parallel=True,
    )
    return ds

# %%
#Compute unweighted spatial mean for each region
def region_mean(ds, mask_da, region_names):
    grouped = ds.where(mask_da.notnull()).groupby(mask_da)
    reg_mean = grouped.mean(["lat", "lon"])
    reg_mean = reg_mean.rename({mask_da.name: "region"})
    reg_mean = reg_mean.assign_coords(region=("region", region_names))
    return reg_mean

# %%
#Write dataset to NetCDF
def write(ds, fp):
    ds = ds.chunk({"time": -1})
    ds.to_netcdf(fp + ".nc")

# %% [markdown]
# ### Average over regions

# %% [markdown]
# Dictionary of variables to process.
#
# Organised with the variable name as the key, then a list as follows:
# `[path_to_open, lat_name, lon_name, path_to_write, var_name, new_var_name]`

# %%
for key, values in zip(variables.keys(), variables.values()):
    for year in years:
        print(f"Processing {key} for year: {year}")

        files_to_open = [
            f"{values[0]}{key}_AUST-04_ERA5_historical_hres_BOM_BARRA-C2_v1_1hr_{year}{m}-{year}{m}.nc"
            for m in month_str
        ]
        print(f"Opening files: {os.path.basename(files_to_open[0])} ...")

        ds = open_hourly(files_to_open, slice(-44, -10), slice(125, 154), values[1], values[2])

        # Create raster mask for filtered regions
        mask = regions.mask(ds, lon_name="lon", lat_name="lat")
        mask.name = "region_id"

        # Compute regional means
        reg_ds = region_mean(ds, mask, gdf["GCC_NAME21"].tolist())

        # Rename variable
        if values[4] in reg_ds:
            reg_ds = reg_ds.rename({values[4]: values[5]})

        fp = values[3] + f"_{year}"
        print(f"Writing to: {fp}.nc")
        write(reg_ds, fp)

print("All done.")
# Out:
# Processing tas for year: 2021
# Opening files: tas_AUST-04_ERA5_historical_hres_BOM_BARRA-C2_v1_1hr_202101-202101.nc ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 11
#       5 files_to_open = [
#       6     f"{values[0]}{key}_AUST-04_ERA5_historical_hres_BOM_BARRA-C2_v1_1hr_{year}{m}-{year}{m}.nc"
#       7     for m in month_str
#       8 ]
#       9 print(f"Opening files: {os.path.basename(files_to_open[0])} ...")
# ---> 11 ds = open_hourly(files_to_open, slice(-44, -10), slice(125, 154), values[1], values[2])
#      13 # Create raster mask for filtered regions
#      14 mask = regions.mask(ds, lon_name="lon", lat_name="lat")
#
# Cell In[38], line 8, in open_hourly(file_list, lat_slice, lon_slice, lat_name, lon_name)
#       5     ds = ds.rename({lat_name: "lat", lon_name: "lon"})
#       6     return ds.sel(lon=lon_slice, lat=lat_slice)
# ----> 8 ds = xr.open_mfdataset(
#       9     file_list,
#      10     preprocess=preprocess,
#      11     chunks={"time": "200MB"},
#      12     combine="by_coords",
#      13     parallel=True,
#      14 )
#      15 return ds
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/xarray/backends/api.py:1568, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1565 open_kwargs = dict(engine=engine, chunks=chunks or {}, **kwargs)
#    1567 if parallel:
# -> 1568     import dask
#    1570     # wrap the open_dataset, getattr, and preprocess with delayed
#    1571     open_ = dask.delayed(open_dataset)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/__init__.py:5
#       3 from dask import config, datasets
#       4 from dask._version import get_versions
# ----> 5 from dask.base import (
#       6     annotate,
#       7     compute,
#       8     get_annotations,
#       9     is_dask_collection,
#      10     optimize,
#      11     persist,
#      12     visualize,
#      13 )
#      14 from dask.core import istask
#      15 from dask.delayed import delayed
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/base.py:1041
#    1032     from dask import threaded
#    1034     named_schedulers.update(
#    1035         {
#    1036             "threads": threaded.get,
#    1037             "threading": threaded.get,
#    1038         }
#    1039     )
# -> 1041     from dask import multiprocessing as dask_multiprocessing
#    1043     named_schedulers.update(
#    1044         {
#    1045             "processes": dask_multiprocessing.get,
#    1046             "multiprocessing": dask_multiprocessing.get,
#    1047         }
#    1048     )
#    1051 get_err_msg = """
#    1052 The get= keyword has been removed.
#    1053
#    (...)
#    1067     x.compute(scheduler=client)
#    1068 """.strip()
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.07/lib/python3.10/site-packages/dask/multiprocessing.py:19
#      17 from dask import config
#      18 from dask.local import MultiprocessingPoolExecutor, get_async, reraise
# ---> 19 from dask.optimization import cull, fuse
#      20 from dask.system import CPU_COUNT
#      21 from dask.typing import Key
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:975, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1074, in get_data(self, path)
#
# KeyboardInterrupt:

# %% [markdown]
# # Close cluster
