# %%
import sys
import metpy.calc as mpcalc
import metpy.units as units
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import tqdm
from dask.distributed import Client
import pandas as pd

sys.path.append('/g/data/ng72/ab4502/hot-cloudy/modules/')
from fronts import *

# %%
client = Client()
client
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 43373 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:34199' processes=4 threads=4, memory=18.00 GiB>
# 2025-09-15 16:11:47,463 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 0, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 0, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 0, 7))
# new run_spec: Alias(('rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 0, 7)->('rechunk-split-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 0, 7))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 0, 7)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 0, 7)})
#
# 2025-09-15 16:11:47,464 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 0, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 0, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 0, 7))
# new run_spec: Alias(('rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 0, 7)->('rechunk-split-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 0, 7))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 0, 7)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 0, 7)})
#
# 2025-09-15 16:11:49,844 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 10, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 10, 7)->('rechunk-split-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 10, 7))
# new run_spec: Alias(('rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 10, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 10, 7))
# old dependencies: {('rechunk-split-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 10, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d7aa9eda017879f169928ac9197b0004', 0, 10, 7)})
#
# 2025-09-15 16:11:49,847 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 10, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 10, 7)->('rechunk-split-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 10, 7))
# new run_spec: Alias(('rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 10, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 10, 7))
# old dependencies: {('rechunk-split-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 10, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3d5a01dd72fdf5234df4d8aa916b11b7', 0, 10, 7)})
#
# 2025-09-15 16:11:57,248 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 0, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 0, 1))
# new run_spec: Alias(('rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 0, 1)->('rechunk-split-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 0, 1))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 0, 1)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 0, 1)})
#
# 2025-09-15 16:11:57,249 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 0, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 0, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 0, 6))
# new run_spec: Alias(('rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 0, 6)->('rechunk-split-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 0, 6))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 0, 6)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 0, 6)})
#
# 2025-09-15 16:11:59,590 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 10, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 10, 4)->('rechunk-split-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 10, 4))
# new run_spec: Alias(('rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 10, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 10, 4))
# old dependencies: {('rechunk-split-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 10, 4)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-3e2ccf233f5f393791adca4c7baae012', 0, 10, 4)})
#
# 2025-09-15 16:11:59,594 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 9, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 9, 9)->('rechunk-split-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 9, 9))
# new run_spec: Alias(('rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 9, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 9, 9))
# old dependencies: {('rechunk-split-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 9, 9)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9a4d9a2cb9323e6408bb2b13807cbba4', 0, 9, 9)})
#
# 2025-09-15 16:12:07,387 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 0, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 0, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 0, 7))
# new run_spec: Alias(('rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 0, 7)->('rechunk-split-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 0, 7))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 0, 7)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 0, 7)})
#
# 2025-09-15 16:12:07,388 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 0, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 0, 5)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 0, 5))
# new run_spec: Alias(('rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 0, 5)->('rechunk-split-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 0, 5))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 0, 5)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 0, 5)})
#
# 2025-09-15 16:12:10,136 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 10, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 10, 3)->('rechunk-split-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 10, 3))
# new run_spec: Alias(('rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 10, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 10, 3))
# old dependencies: {('rechunk-split-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 10, 3)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-52dbef933dd9657b85f0a60c580ef44b', 0, 10, 3)})
#
# 2025-09-15 16:12:10,137 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 9, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 9, 9)->('rechunk-split-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 9, 9))
# new run_spec: Alias(('rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 9, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 9, 9))
# old dependencies: {('rechunk-split-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 9, 9)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-b6b4e79e8688db7113a540c3a605af0d', 0, 9, 9)})
#
# 2025-09-15 16:12:18,075 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 0, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 0, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 0, 4))
# new run_spec: Alias(('rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 0, 4)->('rechunk-split-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 0, 4))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 0, 4)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 0, 4)})
#
# 2025-09-15 16:12:18,079 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 0, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 0, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 0, 9))
# new run_spec: Alias(('rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 0, 9)->('rechunk-split-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 0, 9))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 0, 9)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 0, 9)})
#
# 2025-09-15 16:12:20,390 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 10, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 10, 8)->('rechunk-split-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 10, 8))
# new run_spec: Alias(('rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 10, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 10, 8))
# old dependencies: {('rechunk-split-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 10, 8)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4fea845cf7484aac8794bcd5beb6cd7c', 0, 10, 8)})
#
# 2025-09-15 16:12:20,392 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 9, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 9, 5)->('rechunk-split-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 9, 5))
# new run_spec: Alias(('rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 9, 5)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 9, 5))
# old dependencies: {('rechunk-split-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 9, 5)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-efe21cdc27d5150868ba031777616d92', 0, 9, 5)})
#
# 2025-09-15 16:12:28,581 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-4141a35fa723f618a11a583c20c62d21', 0, 0, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-4141a35fa723f618a11a583c20c62d21', 0, 0, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4141a35fa723f618a11a583c20c62d21', 0, 0, 6))
# new run_spec: Alias(('rechunk-merge-4141a35fa723f618a11a583c20c62d21', 0, 0, 6)->('rechunk-split-rechunk-merge-4141a35fa723f618a11a583c20c62d21', 0, 0, 6))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4141a35fa723f618a11a583c20c62d21', 0, 0, 6)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-4141a35fa723f618a11a583c20c62d21', 0, 0, 6)})
#
# 2025-09-15 16:12:28,583 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-7bf6398e4631f1901d2cfb5d1cb800eb', 0, 0, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-7bf6398e4631f1901d2cfb5d1cb800eb', 0, 0, 5)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-7bf6398e4631f1901d2cfb5d1cb800eb', 0, 0, 5))
# new run_spec: Alias(('rechunk-merge-7bf6398e4631f1901d2cfb5d1cb800eb', 0, 0, 5)->('rechunk-split-rechunk-merge-7bf6398e4631f1901d2cfb5d1cb800eb', 0, 0, 5))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-7bf6398e4631f1901d2cfb5d1cb800eb', 0, 0, 5)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-7bf6398e4631f1901d2cfb5d1cb800eb', 0, 0, 5)})
#
# 2025-09-15 16:12:40,246 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 0, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 0, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 0, 8))
# new run_spec: Alias(('rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 0, 8)->('rechunk-split-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 0, 8))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 0, 8)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 0, 8)})
#
# 2025-09-15 16:12:40,247 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 0, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 0, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 0, 8))
# new run_spec: Alias(('rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 0, 8)->('rechunk-split-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 0, 8))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 0, 8)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 0, 8)})
#
# 2025-09-15 16:12:41,777 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 9, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 9, 1)->('rechunk-split-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 9, 1))
# new run_spec: Alias(('rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 9, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 9, 1))
# old dependencies: {('rechunk-split-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 9, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-69b4e21e35b202792798f264fd22942b', 0, 9, 1)})
#
# 2025-09-15 16:12:41,779 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 10, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 10, 4)->('rechunk-split-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 10, 4))
# new run_spec: Alias(('rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 10, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 10, 4))
# old dependencies: {('rechunk-split-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 10, 4)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-f5c1aaaa0c98496c6fe19ba8996adfac', 0, 10, 4)})
#
# 2025-09-15 16:12:50,742 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 0, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 0, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 0, 9))
# new run_spec: Alias(('rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 0, 9)->('rechunk-split-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 0, 9))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 0, 9)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 0, 9)})
#
# 2025-09-15 16:12:50,744 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 0, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 0, 1))
# new run_spec: Alias(('rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 0, 1)->('rechunk-split-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 0, 1))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 0, 1)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 0, 1)})
#
# 2025-09-15 16:12:53,177 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 9, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 9, 6)->('rechunk-split-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 9, 6))
# new run_spec: Alias(('rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 9, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 9, 6))
# old dependencies: {('rechunk-split-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 9, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ebd802dbe299d0392a792650933a7e3e', 0, 9, 6)})
#
# 2025-09-15 16:12:53,179 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 10, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 10, 9)->('rechunk-split-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 10, 9))
# new run_spec: Alias(('rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 10, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 10, 9))
# old dependencies: {('rechunk-split-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 10, 9)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0c9614a825f4874ebb49e2761f15bc42', 0, 10, 9)})
#
# 2025-09-15 16:13:06,017 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-df97a4f06e9f018296cb94489501d3c6', 0, 10, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-df97a4f06e9f018296cb94489501d3c6', 0, 10, 1)->('rechunk-split-rechunk-merge-df97a4f06e9f018296cb94489501d3c6', 0, 10, 1))
# new run_spec: Alias(('rechunk-merge-df97a4f06e9f018296cb94489501d3c6', 0, 10, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-df97a4f06e9f018296cb94489501d3c6', 0, 10, 1))
# old dependencies: {('rechunk-split-rechunk-merge-df97a4f06e9f018296cb94489501d3c6', 0, 10, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-df97a4f06e9f018296cb94489501d3c6', 0, 10, 1)})
#
# 2025-09-15 16:13:06,019 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-b9e18ac7e1585c0eb491a15adc6ff7bc', 0, 10, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-b9e18ac7e1585c0eb491a15adc6ff7bc', 0, 10, 9)->('rechunk-split-rechunk-merge-b9e18ac7e1585c0eb491a15adc6ff7bc', 0, 10, 9))
# new run_spec: Alias(('rechunk-merge-b9e18ac7e1585c0eb491a15adc6ff7bc', 0, 10, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-b9e18ac7e1585c0eb491a15adc6ff7bc', 0, 10, 9))
# old dependencies: {('rechunk-split-rechunk-merge-b9e18ac7e1585c0eb491a15adc6ff7bc', 0, 10, 9)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-b9e18ac7e1585c0eb491a15adc6ff7bc', 0, 10, 9)})
#
# 2025-09-15 16:13:16,125 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 0, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 0, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 0, 9))
# new run_spec: Alias(('rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 0, 9)->('rechunk-split-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 0, 9))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 0, 9)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 0, 9)})
#
# 2025-09-15 16:13:16,127 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c430d701e84851317d2f754481513606', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c430d701e84851317d2f754481513606', 0, 0, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c430d701e84851317d2f754481513606', 0, 0, 0))
# new run_spec: Alias(('rechunk-merge-c430d701e84851317d2f754481513606', 0, 0, 0)->('rechunk-split-rechunk-merge-c430d701e84851317d2f754481513606', 0, 0, 0))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c430d701e84851317d2f754481513606', 0, 0, 0)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-c430d701e84851317d2f754481513606', 0, 0, 0)})
#
# 2025-09-15 16:13:17,574 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c430d701e84851317d2f754481513606', 0, 9, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c430d701e84851317d2f754481513606', 0, 9, 3)->('rechunk-split-rechunk-merge-c430d701e84851317d2f754481513606', 0, 9, 3))
# new run_spec: Alias(('rechunk-merge-c430d701e84851317d2f754481513606', 0, 9, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c430d701e84851317d2f754481513606', 0, 9, 3))
# old dependencies: {('rechunk-split-rechunk-merge-c430d701e84851317d2f754481513606', 0, 9, 3)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c430d701e84851317d2f754481513606', 0, 9, 3)})
#
# 2025-09-15 16:13:17,575 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 9, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 9, 7)->('rechunk-split-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 9, 7))
# new run_spec: Alias(('rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 9, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 9, 7))
# old dependencies: {('rechunk-split-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 9, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9d47d86f790bff29ff1edf17869b29e9', 0, 9, 7)})
#
# 2025-09-15 16:13:27,130 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 0, 10) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 0, 10)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 0, 10))
# new run_spec: Alias(('rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 0, 10)->('rechunk-split-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 0, 10))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 0, 10)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 0, 10)})
#
# 2025-09-15 16:13:27,131 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 0, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 0, 5)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 0, 5))
# new run_spec: Alias(('rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 0, 5)->('rechunk-split-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 0, 5))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 0, 5)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 0, 5)})
#
# 2025-09-15 16:13:29,548 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 10, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 10, 3)->('rechunk-split-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 10, 3))
# new run_spec: Alias(('rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 10, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 10, 3))
# old dependencies: {('rechunk-split-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 10, 3)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d8458177b61f55b16b62faab69e1a8b8', 0, 10, 3)})
#
# 2025-09-15 16:13:29,550 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 10, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 10, 0)->('rechunk-split-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 10, 0))
# new run_spec: Alias(('rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 10, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 10, 0))
# old dependencies: {('rechunk-split-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 10, 0)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-0147d2be6069ed6b7897544d74f97a62', 0, 10, 0)})
#
# 2025-09-15 16:13:41,079 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 0, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 0, 1))
# new run_spec: Alias(('rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 0, 1)->('rechunk-split-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 0, 1))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 0, 1)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 0, 1)})
#
# 2025-09-15 16:13:41,081 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 0, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 0, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 0, 6))
# new run_spec: Alias(('rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 0, 6)->('rechunk-split-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 0, 6))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 0, 6)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 0, 6)})
#
# 2025-09-15 16:13:42,550 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 10, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 10, 1)->('rechunk-split-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 10, 1))
# new run_spec: Alias(('rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 10, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 10, 1))
# old dependencies: {('rechunk-split-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 10, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-11db95388c003c1881a7312832d58b66', 0, 10, 1)})
#
# 2025-09-15 16:13:42,552 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 9, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 9, 9)->('rechunk-split-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 9, 9))
# new run_spec: Alias(('rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 9, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 9, 9))
# old dependencies: {('rechunk-split-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 9, 9)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-13a76180fe1da630724dadfbbc3c42f8', 0, 9, 9)})
#
# 2025-09-15 16:13:53,297 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-9b6710e1ddeae31c0be72366c0161987', 0, 0, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-9b6710e1ddeae31c0be72366c0161987', 0, 0, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9b6710e1ddeae31c0be72366c0161987', 0, 0, 9))
# new run_spec: Alias(('rechunk-merge-9b6710e1ddeae31c0be72366c0161987', 0, 0, 9)->('rechunk-split-rechunk-merge-9b6710e1ddeae31c0be72366c0161987', 0, 0, 9))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-9b6710e1ddeae31c0be72366c0161987', 0, 0, 9)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-9b6710e1ddeae31c0be72366c0161987', 0, 0, 9)})
#
# 2025-09-15 16:13:53,298 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-629c75d96e9e2b1a7b953bdc71c62e5e', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-629c75d96e9e2b1a7b953bdc71c62e5e', 0, 0, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-629c75d96e9e2b1a7b953bdc71c62e5e', 0, 0, 0))
# new run_spec: Alias(('rechunk-merge-629c75d96e9e2b1a7b953bdc71c62e5e', 0, 0, 0)->('rechunk-split-rechunk-merge-629c75d96e9e2b1a7b953bdc71c62e5e', 0, 0, 0))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-629c75d96e9e2b1a7b953bdc71c62e5e', 0, 0, 0)}
# ...
# old dependencies: {('rechunk-split-rechunk-merge-02f4c27555cb5dc0f3c6837e6086f0f2', 0, 10, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-02f4c27555cb5dc0f3c6837e6086f0f2', 0, 10, 6)})
#
# 2025-09-15 16:39:47,554 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-304512158912b8aeeb38c61214ae769c', 0, 10, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-304512158912b8aeeb38c61214ae769c', 0, 10, 6)->('rechunk-split-rechunk-merge-304512158912b8aeeb38c61214ae769c', 0, 10, 6))
# new run_spec: Alias(('rechunk-merge-304512158912b8aeeb38c61214ae769c', 0, 10, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-304512158912b8aeeb38c61214ae769c', 0, 10, 6))
# old dependencies: {('rechunk-split-rechunk-merge-304512158912b8aeeb38c61214ae769c', 0, 10, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-304512158912b8aeeb38c61214ae769c', 0, 10, 6)})
#
# 2025-09-15 16:39:47,557 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-fc4cf718316f6b20895cd7961de585bf', 0, 10, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-fc4cf718316f6b20895cd7961de585bf', 0, 10, 9)->('rechunk-split-rechunk-merge-fc4cf718316f6b20895cd7961de585bf', 0, 10, 9))
# new run_spec: Alias(('rechunk-merge-fc4cf718316f6b20895cd7961de585bf', 0, 10, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-fc4cf718316f6b20895cd7961de585bf', 0, 10, 9))
# old dependencies: {('rechunk-split-rechunk-merge-fc4cf718316f6b20895cd7961de585bf', 0, 10, 9)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-fc4cf718316f6b20895cd7961de585bf', 0, 10, 9)})
#
# 2025-09-15 16:40:07,566 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-5dcc8208a4626ba593e9e6d40e520bcd', 0, 0, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-5dcc8208a4626ba593e9e6d40e520bcd', 0, 0, 5)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-5dcc8208a4626ba593e9e6d40e520bcd', 0, 0, 5))
# new run_spec: Alias(('rechunk-merge-5dcc8208a4626ba593e9e6d40e520bcd', 0, 0, 5)->('rechunk-split-rechunk-merge-5dcc8208a4626ba593e9e6d40e520bcd', 0, 0, 5))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-5dcc8208a4626ba593e9e6d40e520bcd', 0, 0, 5)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-5dcc8208a4626ba593e9e6d40e520bcd', 0, 0, 5)})
#
# 2025-09-15 16:40:07,568 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-e65c48eba622c73c80b906d150d7bee1', 0, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-e65c48eba622c73c80b906d150d7bee1', 0, 0, 2)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e65c48eba622c73c80b906d150d7bee1', 0, 0, 2))
# new run_spec: Alias(('rechunk-merge-e65c48eba622c73c80b906d150d7bee1', 0, 0, 2)->('rechunk-split-rechunk-merge-e65c48eba622c73c80b906d150d7bee1', 0, 0, 2))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e65c48eba622c73c80b906d150d7bee1', 0, 0, 2)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-e65c48eba622c73c80b906d150d7bee1', 0, 0, 2)})
#
# 2025-09-15 16:40:29,336 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 0, 2)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 0, 2))
# new run_spec: Alias(('rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 0, 2)->('rechunk-split-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 0, 2))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 0, 2)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 0, 2)})
#
# 2025-09-15 16:40:29,338 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 0, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 0, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 0, 3))
# new run_spec: Alias(('rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 0, 3)->('rechunk-split-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 0, 3))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 0, 3)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 0, 3)})
#
# 2025-09-15 16:40:33,397 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 9, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 9, 6)->('rechunk-split-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 9, 6))
# new run_spec: Alias(('rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 9, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 9, 6))
# old dependencies: {('rechunk-split-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 9, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-00b4b1d5150d80ab35da2181a2dac30d', 0, 9, 6)})
#
# 2025-09-15 16:40:33,401 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 9, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 9, 6)->('rechunk-split-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 9, 6))
# new run_spec: Alias(('rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 9, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 9, 6))
# old dependencies: {('rechunk-split-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 9, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-29203c58a1f9e85a19cc80fa039d7391', 0, 9, 6)})
#
# 2025-09-15 16:40:53,148 - tornado.application - ERROR - Uncaught exception GET /individual-task-stream/ws (127.0.0.1)
# HTTPServerRequest(protocol='http', host='gadi-cpu-bdw-0012.gadi.nci.org.au:51221', method='GET', uri='/individual-task-stream/ws', version='HTTP/1.1', remote_ip='127.0.0.1')
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/tornado/web.py", line 1848, in _execute
#     result = await result
#              ^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/tornado/websocket.py", line 277, in get
#     await self.ws_connection.accept_connection(self)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/tornado/websocket.py", line 890, in accept_connection
#     await self._accept_connection(handler)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/tornado/websocket.py", line 973, in _accept_connection
#     await self._receive_frame_loop()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/tornado/websocket.py", line 1130, in _receive_frame_loop
#     self.handler.on_ws_connection_close(self.close_code, self.close_reason)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/tornado/websocket.py", line 599, in on_ws_connection_close
#     self.on_connection_close()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/tornado/websocket.py", line 591, in on_connection_close
#     self.on_close()
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/bokeh/server/views/ws.py", line 308, in on_close
#     self.connection.session.notify_connection_lost()
#     ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.06/lib/python3.11/site-packages/bokeh/server/connection.py", line 65, in session
#     assert self._session is not None
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError
# 2025-09-15 16:40:54,210 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 0, 10) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 0, 10)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 0, 10))
# new run_spec: Alias(('rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 0, 10)->('rechunk-split-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 0, 10))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 0, 10)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 0, 10)})
#
# 2025-09-15 16:40:54,211 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 0, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 0, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 0, 4))
# new run_spec: Alias(('rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 0, 4)->('rechunk-split-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 0, 4))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 0, 4)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 0, 4)})
#
# 2025-09-15 16:40:58,073 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 10, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 10, 4)->('rechunk-split-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 10, 4))
# new run_spec: Alias(('rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 10, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 10, 4))
# old dependencies: {('rechunk-split-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 10, 4)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d084da1938f41bf6b8a465220757f02c', 0, 10, 4)})
#
# 2025-09-15 16:40:58,075 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 10, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 10, 8)->('rechunk-split-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 10, 8))
# new run_spec: Alias(('rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 10, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 10, 8))
# old dependencies: {('rechunk-split-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 10, 8)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ca8efd4f9a273232c8a6a4aa83d6c290', 0, 10, 8)})

# %%
def barra_front(t):

    domain_id = "AUS-11"
    freq = "1hr"
    lat_slice = slice(-45,-10)
    lon_slice = slice(110,160)
    chunks = {}
    smooth = False
    sigma=None

    p = 700

    front_thresh = 8*(units.units.K / units.units.km)
    
    interp_lon = np.arange(110,160.75,0.75)
    interp_lat = np.arange(-45,-9.25,0.75)    

    psl = load_barra_variable("psl",t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    ta = load_barra_variable("ta"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    q = load_barra_variable("hus"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    u = load_barra_variable("ua"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    v = load_barra_variable("va"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    w = load_barra_variable("wa"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    cape = load_barra_variable("CAPE",t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    qfluxu = load_barra_variable("qfluxu",t + dt.timedelta(hours=1.5),t + dt.timedelta(hours=1.5),domain_id,"3hr",lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    qfluxv = load_barra_variable("qfluxv",t + dt.timedelta(hours=1.5),t + dt.timedelta(hours=1.5),domain_id,"3hr",lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    wind = xr.Dataset({"u":u,"v":v,"w":w}).squeeze()
    qflux = np.sqrt(qfluxu**2 + qfluxv**2)

    psl_interp = psl.interp(lat=interp_lat,lon=interp_lon,method="linear")
    ta_interp = ta.interp(lat=interp_lat,lon=interp_lon,method="linear")
    q_interp = q.interp(lat=interp_lat,lon=interp_lon,method="linear")   
    wind_interp = wind.interp(lat=interp_lat,lon=interp_lon,method="linear")   
    qflux_interp = qflux.interp(lat=interp_lat,lon=interp_lon,method="linear")   

    dp_interp = mpcalc.dewpoint_from_specific_humidity(p * units.units.hectopascal, ta_interp, q_interp)
    thetae_interp = mpcalc.equivalent_potential_temperature(p * units.units.hectopascal, ta_interp, dp_interp)    
    dx, dy = mpcalc.lat_lon_grid_deltas(ta_interp.lon,ta_interp.lat)
    ddy_thetae = mpcalc.first_derivative( thetae_interp.squeeze(), delta=dy, axis=0)
    ddx_thetae = mpcalc.first_derivative( thetae_interp.squeeze(), delta=dx, axis=1)
    mag_thetae = np.sqrt( ddx_thetae**2 + ddy_thetae**2).to("K/km") * 100
    mag_thetae_da = xr.DataArray(mag_thetae,dims=["lat","lon"],coords={"lat":ta_interp.lat,"lon":ta_interp.lon})    

    return mag_thetae_da>front_thresh, q_interp, wind_interp, psl_interp, qflux_interp, cape

# %%
dates = pd.read_csv("/g/data/ng72/ab4502/hot-cloudy/data/event_dates_csi0p5_tmax90_carl_andrew_sanaa.csv",index_col=0)
dates["time"] = pd.to_datetime(dates["time"])
dates = dates[(dates.sanaa==1) & (dates.region=="GADE")]
cases = dates.time

# %%
fronts = []
qs = []
winds = []
psls = []
qfluxs = []
capes = []

for time in tqdm.tqdm(cases):
    front, q, wind, psl, qflux, cape = barra_front(time.replace(hour=6))
    fronts.append(front)
    qs.append(q.squeeze())
    winds.append(wind)
    qfluxs.append(qflux.squeeze())
    psls.append(psl.squeeze())
    capes.append(cape.squeeze())
# Out:
# 100%|██████████| 40/40 [08:42<00:00, 13.06s/it]

# %%
qmean = xr.concat(qs,dim="cases").mean("cases").persist()
wind_mean = xr.concat(winds,dim="cases").mean("cases").persist()
fronts_mean = xr.concat(fronts,dim="cases").mean("cases").persist()
psl_mean = xr.concat(psls,dim="cases").mean("cases").persist()
qflux_mean = xr.concat(qfluxs,dim="cases").mean("cases").persist()
cape_mean = xr.concat(capes,dim="cases").mean("cases").persist()

# %%
null_dates = pd.read_csv("/g/data/ng72/ab4502/hot-cloudy/data/null_event_dates_csi0p5_thourly90_nhours7.csv",index_col=0)
null_dates["time"] = pd.to_datetime(null_dates["time"])
null_dates = null_dates[null_dates.region=="GADE"]
null_cases = null_dates.time

# %%
null_fronts = []
null_qs = []
null_winds = []
null_psls = []
null_qfluxs = []
null_capes = []

for time in tqdm.tqdm(null_cases):
    front, q, wind, psl, qflux, cape = barra_front(time.replace(hour=6))
    null_fronts.append(front)
    null_qs.append(q.squeeze())
    null_winds.append(wind)
    null_psls.append(psl.squeeze())
    null_qfluxs.append(qflux.squeeze())
    null_capes.append(cape.squeeze())
# Out:
# 100%|██████████| 50/50 [20:47<00:00, 24.94s/it]

# %%
null_qmean = xr.concat(null_qs,dim="cases").mean("cases").persist()
null_wind_mean = xr.concat(null_winds,dim="cases").mean("cases").persist()
null_fronts_mean = xr.concat(null_fronts,dim="cases").mean("cases").persist()
null_psl_mean = xr.concat(null_psls,dim="cases").mean("cases").persist()
null_qflux_mean = xr.concat(null_qfluxs,dim="cases").mean("cases").persist()
null_cape_mean = xr.concat(null_capes,dim="cases").mean("cases").persist()

# %%
plt.figure(figsize=[16,10])

c=3

ax=plt.subplot(2,3,1,projection=ccrs.PlateCarree())
#xr.plot.contourf(qmean,cmap="Blues",levels=np.linspace(0,0.01,11))
xr.plot.contourf(qflux_mean,cmap="Blues",levels=np.linspace(0,600,11))
#xr.plot.contourf(cape_mean,levels=[0,500],hatches=[None,"////"],colors="none",add_colorbar=False)
wind_mean.coarsen({"lon":c,"lat":c},boundary="trim").mean().plot.quiver(x="lon",y="lat",u="u",v="v",scale=400)
ax.coastlines()
plt.plot(138.6007,-34.9285,marker="o",color="k")
plt.title("Mean ivt (events)")

ax=plt.subplot(2,3,2,projection=ccrs.PlateCarree())
xr.plot.contourf(fronts_mean,cmap="Blues",robust=True,levels=np.linspace(0,0.2,11))
xr.plot.contour(psl_mean,levels=np.linspace(100000,102000,21),colors="k",linewidths=0.5)
ax.coastlines()
plt.plot(138.6007,-34.9285,marker="o",color="k")
plt.title("Frontal freuency (events)\n(theta-e gradient > 8 K/km)")

ax=plt.subplot(2,3,3,projection=ccrs.PlateCarree())
#xr.plot.contourf(wind_mean.w,vmax=0.05,vmin=-0.05,cmap="RdBu",levels=10,extend="both")
xr.plot.contourf(cape_mean,levels=np.linspace(0,2000,11),extend="both")
ax.coastlines()
plt.plot(138.6007,-34.9285,marker="o",color="k")
plt.title("Mean CAPE (events)")





ax=plt.subplot(2,3,4,projection=ccrs.PlateCarree())
#xr.plot.contourf(qmean,cmap="Blues",levels=np.linspace(0,0.01,11))
xr.plot.contourf(null_qflux_mean,cmap="Blues",levels=np.linspace(0,600,11))
#xr.plot.contourf(null_cape_mean,levels=[0,500],hatches=[None,"////"],colors="none",add_colorbar=False)
null_wind_mean.coarsen({"lon":c,"lat":c},boundary="trim").mean().plot.quiver(x="lon",y="lat",u="u",v="v",scale=400)
ax.coastlines()
plt.plot(138.6007,-34.9285,marker="o",color="k")
plt.title("Mean ivt (null events)")

ax=plt.subplot(2,3,5,projection=ccrs.PlateCarree())
xr.plot.contourf(null_fronts_mean,cmap="Blues",robust=True,levels=np.linspace(0,0.2,11))
xr.plot.contour(null_psl_mean,levels=np.linspace(100000,102000,21),colors="k",linewidths=0.5)
ax.coastlines()
plt.plot(138.6007,-34.9285,marker="o",color="k")
plt.title("Frontal freuency (null events)\n(theta-e gradient > 8 K/km)")

ax=plt.subplot(2,3,6,projection=ccrs.PlateCarree())
#xr.plot.contourf(null_wind_mean.w,vmax=0.05,vmin=-0.05,cmap="RdBu",levels=10,extend="both")
xr.plot.contourf(null_cape_mean,levels=np.linspace(0,2000,11),extend="both")
ax.coastlines()
plt.plot(138.6007,-34.9285,marker="o",color="k")
plt.title("Mean upward velocity (null events)")
# Out:
# Text(0.5, 1.0, 'Mean upward velocity (null events)')

# %%
xr.merge([
    qmean,
    wind_mean,
    xr.Dataset({"fronts":fronts_mean}),
    psl_mean,
    xr.Dataset({"qflux":qflux_mean}),
    cape_mean.rename({"lat":"lat2","lon":"lon2"})]).to_netcdf("/g/data/gb02/ab4502/hot_cloudy/adelaide_event_compoisite.nc")

xr.merge([
    null_qmean,
    null_wind_mean,
    xr.Dataset({"fronts":null_fronts_mean}),
    null_psl_mean,
    xr.Dataset({"qflux":null_qflux_mean}),
    null_cape_mean.rename({"lat":"lat2","lon":"lon2"})]).to_netcdf("/g/data/gb02/ab4502/hot_cloudy/adelaide_null_compoisite.nc")
