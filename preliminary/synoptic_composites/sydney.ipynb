# %%
import sys
import metpy.calc as mpcalc
import metpy.units as units
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import tqdm
from dask.distributed import Client
import pandas as pd

sys.path.append('/g/data/ng72/ab4502/hot-cloudy/modules/')
from fronts import *

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:46207' processes=4 threads=4, memory=18.00 GiB>
# 2025-09-15 14:44:24,227 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 0, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 0, 0))
# new run_spec: Alias(('rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 0, 0)->('rechunk-split-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 0, 0))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 0, 0)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 0, 0)})
#
# 2025-09-15 14:44:24,228 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 0, 10) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 0, 10)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 0, 10))
# new run_spec: Alias(('rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 0, 10)->('rechunk-split-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 0, 10))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 0, 10)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 0, 10)})
#
# 2025-09-15 14:44:25,554 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 9, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 9, 4)->('rechunk-split-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 9, 4))
# new run_spec: Alias(('rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 9, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 9, 4))
# old dependencies: {('rechunk-split-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 9, 4)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2ed2a181c47dd93cbf7e5024704d775f', 0, 9, 4)})
#
# 2025-09-15 14:44:25,557 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 10, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 10, 0)->('rechunk-split-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 10, 0))
# new run_spec: Alias(('rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 10, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 10, 0))
# old dependencies: {('rechunk-split-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 10, 0)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bc94aff296c217a8fb90455afc19e884', 0, 10, 0)})
#
# 2025-09-15 14:44:31,375 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 0, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 0, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 0, 8))
# new run_spec: Alias(('rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 0, 8)->('rechunk-split-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 0, 8))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 0, 8)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 0, 8)})
#
# 2025-09-15 14:44:31,376 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 0, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 0, 1))
# new run_spec: Alias(('rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 0, 1)->('rechunk-split-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 0, 1))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 0, 1)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 0, 1)})
#
# 2025-09-15 14:44:33,031 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 9, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 9, 1)->('rechunk-split-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 9, 1))
# new run_spec: Alias(('rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 9, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 9, 1))
# old dependencies: {('rechunk-split-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 9, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-22d20ed65a34c99c96c03afff8acabfb', 0, 9, 1)})
#
# 2025-09-15 14:44:33,033 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 10, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 10, 1)->('rechunk-split-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 10, 1))
# new run_spec: Alias(('rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 10, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 10, 1))
# old dependencies: {('rechunk-split-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 10, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-ee775c4cbe8281b5debc46e49a0cbdc2', 0, 10, 1)})
#
# 2025-09-15 14:44:39,934 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 0, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 0, 1))
# new run_spec: Alias(('rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 0, 1)->('rechunk-split-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 0, 1))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 0, 1)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 0, 1)})
#
# 2025-09-15 14:44:39,935 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 0, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 0, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 0, 3))
# new run_spec: Alias(('rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 0, 3)->('rechunk-split-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 0, 3))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 0, 3)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 0, 3)})
#
# 2025-09-15 14:44:41,127 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 10, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 10, 6)->('rechunk-split-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 10, 6))
# new run_spec: Alias(('rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 10, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 10, 6))
# old dependencies: {('rechunk-split-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 10, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8d237cdbb1890842815c61ba5a427cdf', 0, 10, 6)})
#
# 2025-09-15 14:44:41,130 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 10, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 10, 4)->('rechunk-split-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 10, 4))
# new run_spec: Alias(('rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 10, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 10, 4))
# old dependencies: {('rechunk-split-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 10, 4)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-91f4e3ec22c69fe6b17ea75a1f151db7', 0, 10, 4)})
#
# 2025-09-15 14:44:48,062 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-18e7479c375e62d2e01824119fe7ebb7', 0, 10, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-18e7479c375e62d2e01824119fe7ebb7', 0, 10, 8)->('rechunk-split-rechunk-merge-18e7479c375e62d2e01824119fe7ebb7', 0, 10, 8))
# new run_spec: Alias(('rechunk-merge-18e7479c375e62d2e01824119fe7ebb7', 0, 10, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-18e7479c375e62d2e01824119fe7ebb7', 0, 10, 8))
# old dependencies: {('rechunk-split-rechunk-merge-18e7479c375e62d2e01824119fe7ebb7', 0, 10, 8)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-18e7479c375e62d2e01824119fe7ebb7', 0, 10, 8)})
#
# 2025-09-15 14:44:48,064 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d347a4bdebd49a2c5bc30e479a1dfb3a', 0, 10, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d347a4bdebd49a2c5bc30e479a1dfb3a', 0, 10, 7)->('rechunk-split-rechunk-merge-d347a4bdebd49a2c5bc30e479a1dfb3a', 0, 10, 7))
# new run_spec: Alias(('rechunk-merge-d347a4bdebd49a2c5bc30e479a1dfb3a', 0, 10, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d347a4bdebd49a2c5bc30e479a1dfb3a', 0, 10, 7))
# old dependencies: {('rechunk-split-rechunk-merge-d347a4bdebd49a2c5bc30e479a1dfb3a', 0, 10, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d347a4bdebd49a2c5bc30e479a1dfb3a', 0, 10, 7)})
#
# 2025-09-15 14:44:53,885 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 0, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 0, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 0, 8))
# new run_spec: Alias(('rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 0, 8)->('rechunk-split-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 0, 8))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 0, 8)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 0, 8)})
#
# 2025-09-15 14:44:53,886 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 0, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 0, 5)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 0, 5))
# new run_spec: Alias(('rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 0, 5)->('rechunk-split-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 0, 5))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 0, 5)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 0, 5)})
#
# 2025-09-15 14:44:55,061 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 10, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 10, 6)->('rechunk-split-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 10, 6))
# new run_spec: Alias(('rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 10, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 10, 6))
# old dependencies: {('rechunk-split-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 10, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-82ad8908064110b63a06daada2cfa160', 0, 10, 6)})
#
# 2025-09-15 14:44:55,064 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 10, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 10, 8)->('rechunk-split-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 10, 8))
# new run_spec: Alias(('rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 10, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 10, 8))
# old dependencies: {('rechunk-split-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 10, 8)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1954b677829bc7e371520e2f9084842b', 0, 10, 8)})
#
# 2025-09-15 14:45:02,217 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 0, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 0, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 0, 7))
# new run_spec: Alias(('rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 0, 7)->('rechunk-split-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 0, 7))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 0, 7)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 0, 7)})
#
# 2025-09-15 14:45:02,219 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 0, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 0, 2)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 0, 2))
# new run_spec: Alias(('rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 0, 2)->('rechunk-split-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 0, 2))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 0, 2)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 0, 2)})
#
# 2025-09-15 14:45:03,707 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 9, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 9, 0)->('rechunk-split-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 9, 0))
# new run_spec: Alias(('rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 9, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 9, 0))
# old dependencies: {('rechunk-split-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 9, 0)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-94658f37c1a49d48d01afe3fd75c74b9', 0, 9, 0)})
#
# 2025-09-15 14:45:03,710 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 10, 10) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 10, 10)->('rechunk-split-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 10, 10))
# new run_spec: Alias(('rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 10, 10)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 10, 10))
# old dependencies: {('rechunk-split-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 10, 10)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-fa1108c631cef057dc051d8d2b969056', 0, 10, 10)})
#
# 2025-09-15 14:45:10,107 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 0, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 0, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 0, 6))
# new run_spec: Alias(('rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 0, 6)->('rechunk-split-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 0, 6))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 0, 6)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 0, 6)})
#
# 2025-09-15 14:45:10,108 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 0, 10) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 0, 10)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 0, 10))
# new run_spec: Alias(('rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 0, 10)->('rechunk-split-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 0, 10))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 0, 10)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 0, 10)})
#
# 2025-09-15 14:45:11,394 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 9, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 9, 6)->('rechunk-split-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 9, 6))
# new run_spec: Alias(('rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 9, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 9, 6))
# old dependencies: {('rechunk-split-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 9, 6)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-bd8392c2fbe00ed089344d8abe9cfa68', 0, 9, 6)})
#
# 2025-09-15 14:45:11,396 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 10, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 10, 7)->('rechunk-split-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 10, 7))
# new run_spec: Alias(('rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 10, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 10, 7))
# old dependencies: {('rechunk-split-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 10, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-36b5c2f10d2d444978da2185217cf914', 0, 10, 7)})
#
# 2025-09-15 14:45:18,352 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 0, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 0, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 0, 8))
# new run_spec: Alias(('rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 0, 8)->('rechunk-split-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 0, 8))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 0, 8)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 0, 8)})
#
# 2025-09-15 14:45:18,354 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 0, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 0, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 0, 8))
# new run_spec: Alias(('rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 0, 8)->('rechunk-split-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 0, 8))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 0, 8)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 0, 8)})
#
# 2025-09-15 14:45:19,594 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 10, 8) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 10, 8)->('rechunk-split-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 10, 8))
# new run_spec: Alias(('rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 10, 8)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 10, 8))
# old dependencies: {('rechunk-split-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 10, 8)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-126cc12b646d49f38fa81bad1aec6b1a', 0, 10, 8)})
#
# 2025-09-15 14:45:19,596 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 9, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 9, 2)->('rechunk-split-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 9, 2))
# new run_spec: Alias(('rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 9, 2)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 9, 2))
# old dependencies: {('rechunk-split-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 9, 2)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2b2b3c7a63bb2dc8a6bae1b254b1e10f', 0, 9, 2)})
#
# 2025-09-15 14:45:26,202 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 0, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 0, 0))
# new run_spec: Alias(('rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 0, 0)->('rechunk-split-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 0, 0))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 0, 0)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 0, 0)})
#
# 2025-09-15 14:45:26,204 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 0, 6) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 0, 6)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 0, 6))
# new run_spec: Alias(('rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 0, 6)->('rechunk-split-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 0, 6))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 0, 6)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 0, 6)})
#
# 2025-09-15 14:45:27,369 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 9, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 9, 4)->('rechunk-split-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 9, 4))
# new run_spec: Alias(('rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 9, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 9, 4))
# old dependencies: {('rechunk-split-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 9, 4)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2c4dbdf370cbb81d0988e1ce68162afc', 0, 9, 4)})
#
# 2025-09-15 14:45:27,370 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 10, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 10, 3)->('rechunk-split-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 10, 3))
# new run_spec: Alias(('rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 10, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 10, 3))
# old dependencies: {('rechunk-split-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 10, 3)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-21b7fa661076d39a93a317d8f1332e53', 0, 10, 3)})
#
# 2025-09-15 14:45:35,411 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 0, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 0, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 0, 9))
# new run_spec: Alias(('rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 0, 9)->('rechunk-split-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 0, 9))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 0, 9)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 0, 9)})
#
# 2025-09-15 14:45:35,412 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 0, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 0, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 0, 3))
# new run_spec: Alias(('rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 0, 3)->('rechunk-split-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 0, 3))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 0, 3)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 0, 3)})
#
# 2025-09-15 14:45:36,600 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 10, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 10, 3)->('rechunk-split-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 10, 3))
# new run_spec: Alias(('rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 10, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 10, 3))
# old dependencies: {('rechunk-split-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 10, 3)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-1e660b428f8486da38ff564d41102d48', 0, 10, 3)})
#
# 2025-09-15 14:45:36,602 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 10, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 10, 1)->('rechunk-split-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 10, 1))
# new run_spec: Alias(('rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 10, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 10, 1))
# old dependencies: {('rechunk-split-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 10, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-af7829fb8742807070003d084bff9e11', 0, 10, 1)})
#
# 2025-09-15 14:45:44,318 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-309b3b0c83143c7f4d77ea3089b709bb', 0, 10, 2) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-309b3b0c83143c7f4d77ea3089b709bb', 0, 10, 2)->('rechunk-split-rechunk-merge-309b3b0c83143c7f4d77ea3089b709bb', 0, 10, 2))
# new run_spec: Alias(('rechunk-merge-309b3b0c83143c7f4d77ea3089b709bb', 0, 10, 2)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-309b3b0c83143c7f4d77ea3089b709bb', 0, 10, 2))
# old dependencies: {('rechunk-split-rechunk-merge-309b3b0c83143c7f4d77ea3089b709bb', 0, 10, 2)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-309b3b0c83143c7f4d77ea3089b709bb', 0, 10, 2)})
#
# 2025-09-15 14:45:44,321 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-8991572d51c3a6a1306449194fef3134', 0, 10, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-8991572d51c3a6a1306449194fef3134', 0, 10, 1)->('rechunk-split-rechunk-merge-8991572d51c3a6a1306449194fef3134', 0, 10, 1))
# new run_spec: Alias(('rechunk-merge-8991572d51c3a6a1306449194fef3134', 0, 10, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8991572d51c3a6a1306449194fef3134', 0, 10, 1))
# old dependencies: {('rechunk-split-rechunk-merge-8991572d51c3a6a1306449194fef3134', 0, 10, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8991572d51c3a6a1306449194fef3134', 0, 10, 1)})
#
# 2025-09-15 14:45:52,157 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-d8285387e9ad2837f38c65ce36123ea0', 0, 0, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-d8285387e9ad2837f38c65ce36123ea0', 0, 0, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d8285387e9ad2837f38c65ce36123ea0', 0, 0, 7))
# new run_spec: Alias(('rechunk-merge-d8285387e9ad2837f38c65ce36123ea0', 0, 0, 7)->('rechunk-split-rechunk-merge-d8285387e9ad2837f38c65ce36123ea0', 0, 0, 7))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-d8285387e9ad2837f38c65ce36123ea0', 0, 0, 7)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-d8285387e9ad2837f38c65ce36123ea0', 0, 0, 7)})
#
# 2025-09-15 14:45:52,159 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c00b58145a1bc8607bca0614af29be83', 0, 0, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c00b58145a1bc8607bca0614af29be83', 0, 0, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c00b58145a1bc8607bca0614af29be83', 0, 0, 4))
# new run_spec: Alias(('rechunk-merge-c00b58145a1bc8607bca0614af29be83', 0, 0, 4)->('rechunk-split-rechunk-merge-c00b58145a1bc8607bca0614af29be83', 0, 0, 4))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c00b58145a1bc8607bca0614af29be83', 0, 0, 4)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-c00b58145a1bc8607bca0614af29be83', 0, 0, 4)})
#
# ...
#
# 2025-09-15 15:03:02,091 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c256b050da6520ffa3d59dc407973853', 0, 10, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c256b050da6520ffa3d59dc407973853', 0, 10, 7)->('rechunk-split-rechunk-merge-c256b050da6520ffa3d59dc407973853', 0, 10, 7))
# new run_spec: Alias(('rechunk-merge-c256b050da6520ffa3d59dc407973853', 0, 10, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c256b050da6520ffa3d59dc407973853', 0, 10, 7))
# old dependencies: {('rechunk-split-rechunk-merge-c256b050da6520ffa3d59dc407973853', 0, 10, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c256b050da6520ffa3d59dc407973853', 0, 10, 7)})
#
# 2025-09-15 15:03:02,092 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-211d2a967c683fda69d3fa75f1ce63a6', 0, 10, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-211d2a967c683fda69d3fa75f1ce63a6', 0, 10, 9)->('rechunk-split-rechunk-merge-211d2a967c683fda69d3fa75f1ce63a6', 0, 10, 9))
# new run_spec: Alias(('rechunk-merge-211d2a967c683fda69d3fa75f1ce63a6', 0, 10, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-211d2a967c683fda69d3fa75f1ce63a6', 0, 10, 9))
# old dependencies: {('rechunk-split-rechunk-merge-211d2a967c683fda69d3fa75f1ce63a6', 0, 10, 9)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-211d2a967c683fda69d3fa75f1ce63a6', 0, 10, 9)})
#
# 2025-09-15 15:03:16,517 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-2f500aed21a8202b677a3ea250210e4b', 0, 10, 5) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-2f500aed21a8202b677a3ea250210e4b', 0, 10, 5)->('rechunk-split-rechunk-merge-2f500aed21a8202b677a3ea250210e4b', 0, 10, 5))
# new run_spec: Alias(('rechunk-merge-2f500aed21a8202b677a3ea250210e4b', 0, 10, 5)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2f500aed21a8202b677a3ea250210e4b', 0, 10, 5))
# old dependencies: {('rechunk-split-rechunk-merge-2f500aed21a8202b677a3ea250210e4b', 0, 10, 5)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-2f500aed21a8202b677a3ea250210e4b', 0, 10, 5)})
#
# 2025-09-15 15:03:16,520 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-e22442d7af362eb2073ccef46694c93d', 0, 9, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-e22442d7af362eb2073ccef46694c93d', 0, 9, 7)->('rechunk-split-rechunk-merge-e22442d7af362eb2073ccef46694c93d', 0, 9, 7))
# new run_spec: Alias(('rechunk-merge-e22442d7af362eb2073ccef46694c93d', 0, 9, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e22442d7af362eb2073ccef46694c93d', 0, 9, 7))
# old dependencies: {('rechunk-split-rechunk-merge-e22442d7af362eb2073ccef46694c93d', 0, 9, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e22442d7af362eb2073ccef46694c93d', 0, 9, 7)})
#
# 2025-09-15 15:03:27,373 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 0, 4) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 0, 4)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 0, 4))
# new run_spec: Alias(('rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 0, 4)->('rechunk-split-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 0, 4))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 0, 4)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 0, 4)})
#
# 2025-09-15 15:03:27,375 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 0, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 0, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 0, 1))
# new run_spec: Alias(('rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 0, 1)->('rechunk-split-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 0, 1))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 0, 1)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 0, 1)})
#
# 2025-09-15 15:03:30,837 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 9, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 9, 0)->('rechunk-split-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 9, 0))
# new run_spec: Alias(('rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 9, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 9, 0))
# old dependencies: {('rechunk-split-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 9, 0)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-e105f66ca6d0e62e52b1147f76a0f7c3', 0, 9, 0)})
#
# 2025-09-15 15:03:30,838 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 10, 1) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 10, 1)->('rechunk-split-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 10, 1))
# new run_spec: Alias(('rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 10, 1)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 10, 1))
# old dependencies: {('rechunk-split-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 10, 1)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-4f2ef4d19296937cde19f30d4fd66342', 0, 10, 1)})
#
# 2025-09-15 15:03:44,208 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 0, 3) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 0, 3)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 0, 3))
# new run_spec: Alias(('rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 0, 3)->('rechunk-split-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 0, 3))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 0, 3)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 0, 3)})
#
# 2025-09-15 15:03:44,209 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 0, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 0, 0))
# new run_spec: Alias(('rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 0, 0)->('rechunk-split-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 0, 0))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 0, 0)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 0, 0)})
#
# 2025-09-15 15:03:46,418 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 9, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 9, 7)->('rechunk-split-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 9, 7))
# new run_spec: Alias(('rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 9, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 9, 7))
# old dependencies: {('rechunk-split-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 9, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c56260045d89885bfbdc837081cb8a3d', 0, 9, 7)})
#
# 2025-09-15 15:03:46,419 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 10, 7) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 10, 7)->('rechunk-split-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 10, 7))
# new run_spec: Alias(('rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 10, 7)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 10, 7))
# old dependencies: {('rechunk-split-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 10, 7)}
# new dependencies: frozenset({('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-c103b8c877b3c78e584527d01ce8a395', 0, 10, 7)})
#
# 2025-09-15 15:03:57,075 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-56c4fb3c431e4f562cbda50826aced16', 0, 0, 0) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-56c4fb3c431e4f562cbda50826aced16', 0, 0, 0)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-56c4fb3c431e4f562cbda50826aced16', 0, 0, 0))
# new run_spec: Alias(('rechunk-merge-56c4fb3c431e4f562cbda50826aced16', 0, 0, 0)->('rechunk-split-rechunk-merge-56c4fb3c431e4f562cbda50826aced16', 0, 0, 0))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-56c4fb3c431e4f562cbda50826aced16', 0, 0, 0)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-56c4fb3c431e4f562cbda50826aced16', 0, 0, 0)})
#
# 2025-09-15 15:03:57,077 - distributed.scheduler - WARNING - Detected different `run_spec` for key ('rechunk-merge-8a759b88be40b37eda540f02a0a0fc81', 0, 0, 9) between two consecutive calls to `update_graph`. This can cause failures and deadlocks down the line. Please ensure unique key names. If you are using a standard dask collections, consider releasing all the data before resubmitting another computation. More details and help can be found at https://github.com/dask/dask/issues/9888.
# Debugging information
# ---------------------
# old task state: released
# old run_spec: Alias(('rechunk-merge-8a759b88be40b37eda540f02a0a0fc81', 0, 0, 9)->('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8a759b88be40b37eda540f02a0a0fc81', 0, 0, 9))
# new run_spec: Alias(('rechunk-merge-8a759b88be40b37eda540f02a0a0fc81', 0, 0, 9)->('rechunk-split-rechunk-merge-8a759b88be40b37eda540f02a0a0fc81', 0, 0, 9))
# old dependencies: {('interpnd-interpnd_0-rechunk-split-transpose-rechunk-merge-8a759b88be40b37eda540f02a0a0fc81', 0, 0, 9)}
# new dependencies: frozenset({('rechunk-split-rechunk-merge-8a759b88be40b37eda540f02a0a0fc81', 0, 0, 9)})

# %%
def barra_front(t):

    domain_id = "AUS-11"
    freq = "1hr"
    lat_slice = slice(-45,-10)
    lon_slice = slice(110,160)
    chunks = {}
    smooth = False
    sigma=None

    p = 700

    front_thresh = 8*(units.units.K / units.units.km)
    
    interp_lon = np.arange(110,160.75,0.75)
    interp_lat = np.arange(-45,-9.25,0.75)    

    psl = load_barra_variable("psl",t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    ta = load_barra_variable("ta"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    q = load_barra_variable("hus"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    u = load_barra_variable("ua"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    v = load_barra_variable("va"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    w = load_barra_variable("wa"+str(p),t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    cape = load_barra_variable("CAPE",t,t,domain_id,freq,lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    qfluxu = load_barra_variable("qfluxu",t + dt.timedelta(hours=1.5),t + dt.timedelta(hours=1.5),domain_id,"3hr",lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    qfluxv = load_barra_variable("qfluxv",t + dt.timedelta(hours=1.5),t + dt.timedelta(hours=1.5),domain_id,"3hr",lat_slice,lon_slice,chunks=chunks,smooth=smooth,sigma=sigma)
    wind = xr.Dataset({"u":u,"v":v,"w":w}).squeeze()
    qflux = np.sqrt(qfluxu**2 + qfluxv**2)

    psl_interp = psl.interp(lat=interp_lat,lon=interp_lon,method="linear")
    ta_interp = ta.interp(lat=interp_lat,lon=interp_lon,method="linear")
    q_interp = q.interp(lat=interp_lat,lon=interp_lon,method="linear")   
    wind_interp = wind.interp(lat=interp_lat,lon=interp_lon,method="linear")   
    qflux_interp = qflux.interp(lat=interp_lat,lon=interp_lon,method="linear")   

    dp_interp = mpcalc.dewpoint_from_specific_humidity(p * units.units.hectopascal, ta_interp, q_interp)
    thetae_interp = mpcalc.equivalent_potential_temperature(p * units.units.hectopascal, ta_interp, dp_interp)    
    dx, dy = mpcalc.lat_lon_grid_deltas(ta_interp.lon,ta_interp.lat)
    ddy_thetae = mpcalc.first_derivative( thetae_interp.squeeze(), delta=dy, axis=0)
    ddx_thetae = mpcalc.first_derivative( thetae_interp.squeeze(), delta=dx, axis=1)
    mag_thetae = np.sqrt( ddx_thetae**2 + ddy_thetae**2).to("K/km") * 100
    mag_thetae_da = xr.DataArray(mag_thetae,dims=["lat","lon"],coords={"lat":ta_interp.lat,"lon":ta_interp.lon})    

    return mag_thetae_da>front_thresh, q_interp, wind_interp, psl_interp, qflux_interp, cape

# %%
dates = pd.read_csv("/g/data/ng72/ab4502/hot-cloudy/data/event_dates_csi0p5_tmax90_carl_andrew_sanaa.csv",index_col=0)
dates["time"] = pd.to_datetime(dates["time"])
dates = dates[(dates.sanaa==1) & (dates.region=="GSYD")]
cases = dates.time

# %%
fronts = []
qs = []
winds = []
psls = []
qfluxs = []
capes = []

for time in tqdm.tqdm(cases):
    front, q, wind, psl, qflux, cape = barra_front(time.replace(hour=6))
    fronts.append(front)
    qs.append(q.squeeze())
    winds.append(wind)
    qfluxs.append(qflux.squeeze())
    psls.append(psl.squeeze())
    capes.append(cape.squeeze())
# Out:
# 100%|██████████| 50/50 [07:39<00:00,  9.19s/it]

# %%
qmean = xr.concat(qs,dim="cases").mean("cases").persist()
wind_mean = xr.concat(winds,dim="cases").mean("cases").persist()
fronts_mean = xr.concat(fronts,dim="cases").mean("cases").persist()
psl_mean = xr.concat(psls,dim="cases").mean("cases").persist()
qflux_mean = xr.concat(qfluxs,dim="cases").mean("cases").persist()
cape_mean = xr.concat(capes,dim="cases").mean("cases").persist()

# %%
null_dates = pd.read_csv("/g/data/ng72/ab4502/hot-cloudy/data/null_event_dates_csi0p5_thourly90_nhours7.csv",index_col=0)
null_dates["time"] = pd.to_datetime(null_dates["time"])
null_dates = null_dates[null_dates.region=="GSYD"]
null_cases = null_dates.time

# %%
null_fronts = []
null_qs = []
null_winds = []
null_psls = []
null_qfluxs = []
null_capes = []

for time in tqdm.tqdm(null_cases):
    front, q, wind, psl, qflux, cape = barra_front(time.replace(hour=6))
    null_fronts.append(front)
    null_qs.append(q.squeeze())
    null_winds.append(wind)
    null_psls.append(psl.squeeze())
    null_qfluxs.append(qflux.squeeze())
    null_capes.append(cape.squeeze())
# Out:
# 100%|██████████| 36/36 [07:23<00:00, 12.32s/it]

# %%
null_qmean = xr.concat(null_qs,dim="cases").mean("cases").persist()
null_wind_mean = xr.concat(null_winds,dim="cases").mean("cases").persist()
null_fronts_mean = xr.concat(null_fronts,dim="cases").mean("cases").persist()
null_psl_mean = xr.concat(null_psls,dim="cases").mean("cases").persist()
null_qflux_mean = xr.concat(null_qfluxs,dim="cases").mean("cases").persist()
null_cape_mean = xr.concat(null_capes,dim="cases").mean("cases").persist()

# %%
plt.figure(figsize=[16,10])

c=3

ax=plt.subplot(2,3,1,projection=ccrs.PlateCarree())
#xr.plot.contourf(qmean,cmap="Blues",levels=np.linspace(0,0.01,11))
xr.plot.contourf(qflux_mean,cmap="Blues",levels=np.linspace(0,600,11))
#xr.plot.contourf(cape_mean,levels=[0,500],hatches=[None,"////"],colors="none",add_colorbar=False)
wind_mean.coarsen({"lon":c,"lat":c},boundary="trim").mean().plot.quiver(x="lon",y="lat",u="u",v="v",scale=400)
ax.coastlines()
plt.plot(151.2057,-33.8727,marker="o",color="k")
plt.title("Mean ivt (events)")

ax=plt.subplot(2,3,2,projection=ccrs.PlateCarree())
xr.plot.contourf(fronts_mean,cmap="Blues",robust=True,levels=np.linspace(0,0.2,11))
xr.plot.contour(psl_mean,levels=np.linspace(100000,102000,21),colors="k",linewidths=0.5)
ax.coastlines()
plt.plot(151.2057,-33.8727,marker="o",color="k")
plt.title("Frontal freuency (events)\n(theta-e gradient > 8 K/km)")

ax=plt.subplot(2,3,3,projection=ccrs.PlateCarree())
#xr.plot.contourf(wind_mean.w,vmax=0.05,vmin=-0.05,cmap="RdBu",levels=10,extend="both")
xr.plot.contourf(cape_mean,levels=np.linspace(0,2000,11),extend="both")
ax.coastlines()
plt.plot(151.2057,-33.8727,marker="o",color="k")
plt.title("Mean CAPE (events)")





ax=plt.subplot(2,3,4,projection=ccrs.PlateCarree())
#xr.plot.contourf(qmean,cmap="Blues",levels=np.linspace(0,0.01,11))
xr.plot.contourf(null_qflux_mean,cmap="Blues",levels=np.linspace(0,600,11))
#xr.plot.contourf(null_cape_mean,levels=[0,500],hatches=[None,"////"],colors="none",add_colorbar=False)
null_wind_mean.coarsen({"lon":c,"lat":c},boundary="trim").mean().plot.quiver(x="lon",y="lat",u="u",v="v",scale=400)
ax.coastlines()
plt.plot(151.2057,-33.8727,marker="o",color="k")
plt.title("Mean ivt (null events)")

ax=plt.subplot(2,3,5,projection=ccrs.PlateCarree())
xr.plot.contourf(null_fronts_mean,cmap="Blues",robust=True,levels=np.linspace(0,0.2,11))
xr.plot.contour(null_psl_mean,levels=np.linspace(100000,102000,21),colors="k",linewidths=0.5)
ax.coastlines()
plt.plot(151.2057,-33.8727,marker="o",color="k")
plt.title("Frontal freuency (null events)\n(theta-e gradient > 8 K/km)")

ax=plt.subplot(2,3,6,projection=ccrs.PlateCarree())
#xr.plot.contourf(null_wind_mean.w,vmax=0.05,vmin=-0.05,cmap="RdBu",levels=10,extend="both")
xr.plot.contourf(null_cape_mean,levels=np.linspace(0,2000,11),extend="both")
ax.coastlines()
plt.plot(151.2057,-33.8727,marker="o",color="k")
plt.title("Mean CAPE (null events)")
# Out:
# Text(0.5, 1.0, 'Mean upward velocity (null events)')

# %%
xr.merge([
    qmean,
    wind_mean,
    xr.Dataset({"fronts":fronts_mean}),
    psl_mean,
    xr.Dataset({"qflux":qflux_mean}),
    cape_mean.rename({"lat":"lat2","lon":"lon2"})]).to_netcdf("/g/data/gb02/ab4502/hot_cloudy/sydney_event_compoisite.nc")

xr.merge([
    null_qmean,
    null_wind_mean,
    xr.Dataset({"fronts":null_fronts_mean}),
    null_psl_mean,
    xr.Dataset({"qflux":null_qflux_mean}),
    null_cape_mean.rename({"lat":"lat2","lon":"lon2"})]).to_netcdf("/g/data/gb02/ab4502/hot_cloudy/sydney_null_compoisite.nc")
